# %% [markdown]
# ## Files Available:
#
# Amazon Sale Report.csv
#
# Sale Report.csv
#
# International Sale Report.csv
#
# May-2022.csv
#
# P L March 2021.csv
#
# Expense IIGF.csv
#
# Cloud Warehouse Comparison.csv
#
# ## Classification:
# ### 🟢 SALES DATA (Used in Project)
#
# International Sale Report.csv
# Contains:
#
# SKU
#
# Qty
#
# Amount
#
# Country
#
# Date
#
# Purpose: Transaction-level sales data.
#
# ## May-2022.csv
# Contains:
#
# SKU
#
# Quantity
#
# Amount
#
# Date
#
# Purpose: Monthly sales data.
#
# These two files will be APPENDED vertically to form the MAIN SALES TABLE.
#
# 🟢 PRODUCT METADATA (Optional Enrichment)
#
# ## Amazon Sale Report.csv
# Contains:
#
# SKU Code
#
# Design No
#
# Stock
#
# Category
#
# Size
#
# Color
#
# Purpose: Product attributes.
#
# Sale Report.csv
# Contains:
#
# SKU
#
# Design
#
# Stock
#
# Category
#
# Size
#
# Color
#
# Purpose: Product lookup table.
#
# These will be used later to add Category / Size / Color using SKU.
